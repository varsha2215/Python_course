# %%
def div(a,b):
    c=a/b
    return c
print(div(2,8))
# Out:
# 0.25

# %%
def div(a,b):
    c=a/b
    print(c)
div(2,8)
# Out:
# 0.25

# %%
def div():
   a=2
   b=8
   c=a/b
   print(c)
div()
# Out:
# 0.25

# %%
def div():
    a=2
    b=8
    c=a/b
    return c
div()
# Out:
# 0.25
