# %%
set1={3,2,3,5,6}
set2={3,7,4,2,9}
print(set1^set2)
print(set1.symmetric_difference(set2))
print(set1.union(set2))# |
print(set1.difference(set2)) # ^
print(set.intersection(set2)) # &
print(set1.issubset(set2)) 
print(set2.issubset(set1))
# Out:
# {4, 5, 6, 7, 9}
# {4, 5, 6, 7, 9}
# {2, 3, 4, 5, 6, 7, 9}
# {5, 6}
# {2, 3, 4, 7, 9}
# False
# False

# %%
#find the frequency of each and every word in agiven sentence
