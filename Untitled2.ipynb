# %%
num=int(input())
val=int(num**0.5)
print(val)
if val==int(val):
    print(f"{num}is perfect square")
else:
    print(f"{num}is not perfect square")
# Out:
#  36
# 6
# 36is perfect square

# %%
n=int(input())
if n%2==0:
    print(f"{num} is even")
if n%2==1:
    print(f"{num} is odd")
# Out:
#  13
# 36 is odd

# %%
n=int(input())
if n%2==0:
    print(f"{num} is even")
else:
    print(f"{num} is odd")"
# Out:
#  12
# 36 is even

# %%
# Out:
#  15
# Fizz
# Buzz

# %%
num=int(input())
if num % 3==0:
    print("fizz")
elif num % 5==0:
     print("buzz")
elif (num%3) and (num%5) ==0:
     print("fizzbuzz")
else:
       print(num)
# Out:
#  30
# fizz

# %%
n=int(input())
if n>0:
    print("+ve")
elif n<0:
    print("-ve")
else:
    print("zero")
# Out:
#  3
# +ve

# %%
num=int(input())
if num> 0 and num % 2==0:
    print(f"{num}is +ve even")
elif num>0:
    print(f"{num}is +ve odd")
elif num<0 and num % 2==0:
    print(f"{num}is -ve even")
else:
    print(f"{num}is -ve odd")
# Out:
#  35
# 35is +ve odd

# %%
#find the smallest number among the three numbers
a = int(input("Enter first number:17 "))
b = int(input("Enter second number:6 "))
c = int(input("Enter third number:8 "))
if a<=b and b<=c and a<=c:
    print("a is smaller")
else:
    print("c is smaller")
# Out:
# Enter first number:17  12
# Enter second number:6  4
# Enter third number:8  2
# c is smaller

# %%
##find the bigger number using nested else among three numbers 
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b:
    if a > c:
        print("Biggest number is:", a)
    else:
        print("Biggest number is:", c)
else:
    if b > c:
        print("Biggest number is:", b)
    else:
        print("Biggest number is:", c)
# Out:
# Enter first number:  15
# Enter second number:  19
# Enter third number:  4
# Biggest number is: 19

# %%
a=[1,9,5,6,9]
target=5
while target in list:
    list1.remove(target)
print(list1)
