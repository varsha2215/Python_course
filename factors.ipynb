# %%
number=int(input())
count=0
for num in range(1,number+1):
    if number%num==0:
       print(num)
# Out:
#  7
# 1
# 7

# %%
n=int(input())
count=0
for factor in range(1,n+1):
    if n% factor==0:
        count+=1
