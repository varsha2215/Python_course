# %%
##
name="varsha"
age=20
marks=[85,98,65,85,78,98]
# my name varsha  and i am a 20 years old
print("my name"+name + "and iam a" +str(age)+"years old")
# Out:
# my namevarshaand iam a20years old

# %%
##1.acess specifiers
#integer -%d
#float -%f
#string -%s
name="varsha"
age=20
marks=[85,98,65,85,78,98]
#my name varsha and iam a 20 years old
print("my name %s and i am a %d years old"%(name,age))
# Out:
# my name varsha and i am a 20 years old

# %%
##output formating
#dot format
#integer -%d
#float -%f
#string -%s
name="varsha"
age=20print("my name {} and i am a {} years old".format(name,age))


marks=[85,98,65,85,78,98]
#my name varsha and iam a 20 years old
# Out:
# my name varsha and i am a 20 years old

# %%
#f- format
name="varsha"
age=20
marks=[85,98,65,85,78,98]
percentage =98.2568
print(f"my name{name}.i am a {age} years old and my percentage is {percentage}")
print(f"my name{name}.i am a {age} yeras old and my percentage is {percentage:.2f}")
# Out:
# my namevarsha.i am a 20 years old and my percentage is 98.2568
# my namevarsha.i am a 20 yeras old and my percentage is 98.26

# %%
num=int(input())
if num>=0:
    print(f'{num} is +ve')
else:
    print(f'{num} is -ve')
# Out:
#  3
# 3 is +ve

# %%
num=int(input())
if num %3==0 and num %5==0:
        print(f"{num}not divisible with both 3 and 5")
else:
    print(f" not divisible with both 3 and 5")
# Out:
#  9
#  not divisible with both 3 and 5

# %%
num=int(input())
val=num ** 0.5
print(val)
if val == int(val):
    print(f"{num}is perfect square")
else:
    print(f"{num} is not perfect square")
# Out:
#  16
# 4.0
# 16is perfect square
