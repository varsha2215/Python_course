# %%
t=(1,2,3,4,"HI",[10,20,30],50)
print(t) 
print(t[5])
print(t[5][1])
# Out:
# (1, 2, 3, 4, 'HI', [10, 20, 30], 50)
# [10, 20, 30]
# 20

# %%
t=(1,2,3,4,"HI",[10,20,30],50)
t[5].append(100)
print(t)
# Out:
# (1, 2, 3, 4, 'HI', [10, 20, 30, 100], 50)

# %%
#define empty tuple
t1=()
t2=()
print(type(t1),type(t2))
# Out:
# <class 'tuple'> <class 'tuple'>

# %%
l1=[10]
t1=(10)
t2=(10,)
print(type(l1),type(t1),type(t2))
# Out:
# <class 'list'> <class 'int'> <class 'tuple'>

# %%
#dictionary cant allow list as key
#if dictionary contains multiple items with key,in that case it updates first item key value with last defined item value
t=(1,2,3,4,"HI",[10,20,30],50)
print(details)
# Out:
# {'name': 'Ravi', 'age': 20, 'course': 'python', 'marks': [85, 90, 86], 'Age': 50}

# %%
#asscess values by using keys
rks':[85,90,86],'age':50}
details{'name':'ravi','age':20,'course':'python','marint(details['course'])
 print(details['age'])
 #updating the dictionary value
    details['age']+=1
details['course']='java'
print(details)
#item assignment
details['location']="india"
print(details)
# Out:
#   Cell In[17], line 2
#     details{'name':'ravi','age':20,'course':'python','marks':[85,90,86],'age':50}
#            ^
# SyntaxError: invalid syntax

# %%
#define empty dictionary
d1={}
d2=dict()
print(type(d1),type(d2))
# Out:
# <class 'dict'> <class 'dict'>

# %%
#dictionary methods
-get value =get(key,default_val):it returns the value if key exists in dictionary otherwise default_val
-update values and add items to dictionary
-update (new_dictionary):dictionary updates with New_dictionary items
-remove items from dictionary
-pop(key):it returns value and remove item if key is exists in dictionary otherwise key error
-popitem():it returns the tuple of key value pair and removes the last item from dictionary
-get keys,value and items from dictionary
-keys():it returns list of dictionary keys
-values():it returns list of dictionary values 
-items():it returns list of tuple key value pair'

# %%
t=(1,2,3,4,"HI",[10,20,30],50)
d={'marks':[85,90,86],'age':50}
details.update(d)
print(details)
# Out:
# {'name': 'ravi', 'age': 50, 'course': 'python', 'marks': [85, 90, 86]}

# %%
import sys
print(sys.getsizeof([1,2,3]))
print(sys.getsizeof([1,2,3]))
# Out:
# 88
# 88
