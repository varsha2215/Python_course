# %%
#remove target element from list of integers
arr=list(map(int,input().split()))
target=int(input())
res=[]
for num in arr:
    if num != target:
        res.append(num)
print(res)
# Out:
#  1 2 3 2 32 32  3 3 3
#  3
# [1, 2, 2, 32, 32]

# %%
arr=list(map(int,input().split()))
target=int(input())
res=[]
n=len(arr)
i=0
while i<n:
     if arr[i] !=target:
        res.append(arr[i])
     i+=1
print(res)
# Out:
#  5 6 7 5
#  5
# [6, 7]

# %%
a=list(map(int,input().split()))
target=int(input())
res=[]

n=len(a)
i=0
while i<n:
    if a[i] ==target:
        a.pop(i)
        n-=1
    else:
        i+=1
print(a)
# Out:
#  5 6 7 7 6
#  6
# [5, 7, 7]

# %%
arr=list(map(int,input().split()))
target=int(input())
res = -1
n = len(arr)
for i in range(n):
    if arr[i] == target:
        res = i
print(res)
# Out:
#  1 2 3 4 5
#  100
# -1
